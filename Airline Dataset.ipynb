# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_excel("C:\\Users\\hp\\Downloads\\Data_Train.xlsx")
a
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
a.shape
# Out:
# (10683, 11)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
a.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
a[a["Route"]==a["Route"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price]
# Index: []

# %%
a["Route"].fillna(a["Route"].mode()[0],inplace=True)
a["Total_Stops"].fillna(a["Total_Stops"].mode()[0],inplace=True)

# %%
a.isnull().sum().sum()
# Out:
# 0

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
a["Date_of_Journey"]=pd.to_datetime(a["Date_of_Journey"])
a["Dep_Time"]=pd.to_datetime(a["Dep_Time"])
a["Arrival_Time"]=pd.to_datetime(a["Arrival_Time"])

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  datetime64[ns]
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10683 non-null  object
#  5   Dep_Time         10683 non-null  datetime64[ns]
#  6   Arrival_Time     10683 non-null  datetime64[ns]
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10683 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: datetime64[ns](3), int64(1), object(7)
# memory usage: 918.2+ KB

# %%
from datetime import datetime as dt

# %%
# Day , month ,departure hours , Minutes , arrival hours arrival minutes

# %%
a["Date"]=a.Date_of_Journey.dt.day
a["Day"]=a.Date_of_Journey.dt.day_name()
a["Month Name"]=a.Date_of_Journey.dt.month_name()
a["Year"]=a.Date_of_Journey.dt.year
a["Dep_Hour"]=a.Dep_Time.dt.hour
a["Dep_Min"]=a.Dep_Time.dt.minute
a["Arrival_Hour"]=a.Arrival_Time.dt.hour
a["Arrival_Min"]=a.Arrival_Time.dt.minute

# %%
a
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-01-05   Kolkata    Banglore
# 2      Jet Airways      2019-09-06     Delhi      Cochin
# 3           IndiGo      2019-12-05   Kolkata    Banglore
# 4           IndiGo      2019-01-03  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-01-03  Banglore   New Delhi
# 10682    Air India      2019-09-05     Delhi      Cochin
#
#                        Route            Dep_Time        Arrival_Time Duration  \
# 0                  BLR → DEL 2022-12-21 22:20:00 2022-03-22 01:10:00   2h 50m
# 1      CCU → IXR → BBI → BLR 2022-12-21 05:50:00 2022-12-21 13:15:00   7h 25m
# ...

# %%
for i in a.columns:
    print(i,"====>",a[i].unique(),"\n\n")
# Out:
# Airline ====> ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']
#
#
# Date_of_Journey ====> ['2019-03-24T00:00:00.000000000' '2019-01-05T00:00:00.000000000'
#  '2019-09-06T00:00:00.000000000' '2019-12-05T00:00:00.000000000'
#  '2019-01-03T00:00:00.000000000' '2019-06-24T00:00:00.000000000'
#  '2019-12-03T00:00:00.000000000' '2019-05-27T00:00:00.000000000'
#  '2019-01-06T00:00:00.000000000' '2019-04-18T00:00:00.000000000'
#  '2019-09-05T00:00:00.000000000' '2019-04-24T00:00:00.000000000'
#  '2019-03-03T00:00:00.000000000' '2019-04-15T00:00:00.000000000'
#  '2019-12-06T00:00:00.000000000' '2019-06-03T00:00:00.000000000'
#  '2019-03-21T00:00:00.000000000' '2019-03-04T00:00:00.000000000'
#  '2019-06-05T00:00:00.000000000' '2019-05-15T00:00:00.000000000'
#  '2019-06-18T00:00:00.000000000' '2019-06-15T00:00:00.000000000'
# ...

# %%
a.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2022-12-21 22:20:00 2022-03-22 01:10:00   2h 50m    non-stop
# 1 2022-12-21 05:50:00 2022-12-21 13:15:00   7h 25m     2 stops
#
#   Additional_Info  Price  Date       Day Month Name  Year  Dep_Hour  Dep_Min  \
# 0         No info   3897    24    Sunday      March  2019        22       20
# 1         No info   7662     5  Saturday    January  2019         5       50
#
#    Arrival_Hour  Arrival_Min
# 0             1           10
# 1            13           15

# %%
# Departure Date Error

# %%
# Find How many different Airlines
# Find how many flights have been fly in each airline .
# Find how many flights have been fly in same source .
# How many States flight have been fly .
# Find how many flights have been land in same destination .
# How many airline have been land in same destination .
# Find how many flights have been fly in each month .
# In which month flight have been fly in maximum and its type and count in each flight .
# How many flight have been fly in each day .
# How many fight have been fly in each day in each month .
# In how many flights have a additional information .
# Find the name of the Airline and its counts which have additional information .
# Find the highest price flight and name of airline .
# What is the price of additional information flight .
# Find the count of Total_Stops .
# Find how many total income have been earn .
# Find have been income earn in each month .
# Find the highest income earn in each month in each date .
# Find the highest income earn in each month in each day .
# In which month people fly most in each month .

# %%
a["Destination"].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
a["Source"].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
a["Destination"].value_counts()
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
a.groupby("Destination")["Airline"].value_counts()
# Out:
# Destination  Airline
# Banglore     Jet Airways                          1256
#              Air India                             512
#              IndiGo                                445
#              SpiceJet                              300
#              Vistara                               183
#              Air Asia                              150
#              GoAir                                  25
# Cochin       Jet Airways                          1586
#              Multiple carriers                    1196
#              Air India                             747
#              IndiGo                                705
#              SpiceJet                               87
#              Air Asia                               80
#              GoAir                                  76
#              Vistara                                45
#              Multiple carriers Premium economy      13
#              Jet Airways Business                    2
# ...

# %%
a["Additional_Info"].value_counts()
# Out:
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
len(a[a["Additional_Info"]!="No info"])
# Out:
# 2338

# %%
a[a["Additional_Info"]!="No info"]["Airline"].value_counts()
# Out:
# Jet Airways             1899
# SpiceJet                 321
# Multiple carriers         96
# Air India                 15
# IndiGo                     3
# Jet Airways Business       3
# Air Asia                   1
# Name: Airline, dtype: int64

# %%
a.groupby("Month Name")["Day"].value_counts()
# Out:
# Month Name  Day
# April       Saturday      94
#             Wednesday     92
#             Monday        89
#             Sunday        82
#             Thursday      67
# December    Friday       493
#             Thursday     259
#             Tuesday      142
#             Wednesday     63
# January     Sunday       342
#             Saturday     277
#             Friday       257
#             Thursday     199
# June        Thursday     858
#             Monday       754
#             Saturday     328
#             Wednesday    282
#             Tuesday      205
#             Friday       109
# March       Sunday       638
#             Wednesday    632
#             Thursday     423
#             Monday       266
#             Friday       162
#             Tuesday       90
# May         Saturday     504
#             Tuesday      497
#             Wednesday    405
#             Monday       382
#             Friday       286
# September   Friday       495
# ...

# %%
a["Month Name"].value_counts().sort_values(ascending=False).reset_index()
# Out:
#        index  Month Name
# 0       June        2536
# 1      March        2211
# 2        May        2074
# 3  September        1406
# 4    January        1075
# 5   December         957
# 6      April         424

# %%
a[a["Month Name"]=="June"]["Airline"].value_counts().reset_index()
# Out:
#                       index  Airline
# 0               Jet Airways      931
# 1                    IndiGo      469
# 2                 Air India      386
# 3         Multiple carriers      341
# 4                  SpiceJet      190
# 5                   Vistara      102
# 6                  Air Asia       69
# 7                     GoAir       45
# 8                    Trujet        1
# 9   Vistara Premium economy        1
# 10     Jet Airways Business        1

# %%
a["Source"].value_counts()
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
# Find How many Airlines

# %%
a["Airline"].value_counts().reset_index()
# Out:
#                                 index  Airline
# 0                         Jet Airways     3849
# 1                              IndiGo     2053
# 2                           Air India     1752
# 3                   Multiple carriers     1196
# 4                            SpiceJet      818
# 5                             Vistara      479
# 6                            Air Asia      319
# 7                               GoAir      194
# 8   Multiple carriers Premium economy       13
# 9                Jet Airways Business        6
# 10            Vistara Premium economy        3
# 11                             Trujet        1

# %%
a.drop(columns=["Dep_Time","Arrival_Time","Date_of_Journey"],inplace=True)

# %%
a
# Out:
#            Airline    Source Destination                  Route Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR   2h 30m
# 10679    Air India   Kolkata    Banglore              CCU → BLR   2h 35m
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       3h
# 10681      Vistara  Banglore   New Delhi              BLR → DEL   2h 40m
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   8h 20m
#
#       Total_Stops Additional_Info  Price  Date        Day Month Name  Year  \
# ...

# %%
# Change inside destination .

# %%
a["Destination"]=a["Destination"].replace("Delhi","New Delhi")

# %%
a["Destination"].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %%
# Change Hour to minute with the help of evel

# %%
a["Duration"]=a["Duration"].str.replace("h","*60").str.replace(" ","+").str.replace("m","*1").apply(eval)

# %%
a["Duration"]
# Out:
# 0         170
# 1         445
# 2        1140
# 3         325
# 4         285
#          ...
# 10678     150
# 10679     155
# 10680     180
# 10681     160
# 10682     500
# Name: Duration, Length: 10683, dtype: int64

# %%
a["Total_Stops"].replace({"non-stop":0,"1 stop":1,"2 stops":2,"3 stops":3,"4 stops":4},inplace=True)

# %%
# Correlation

# %%
a.corr()
# Out:
#               Duration  Total_Stops     Price      Date  Year  Dep_Hour  \
# Duration      1.000000     0.738025  0.506371 -0.038480   NaN  0.002001
# Total_Stops   0.738025     1.000000  0.603883 -0.024156   NaN -0.061490
# Price         0.506371     0.603883  1.000000 -0.165412   NaN  0.006819
# Date         -0.038480    -0.024156 -0.165412  1.000000   NaN -0.002251
# Year               NaN          NaN       NaN       NaN   NaN       NaN
# Dep_Hour      0.002001    -0.061490  0.006819 -0.002251   NaN  1.000000
# Dep_Min      -0.018938    -0.002591 -0.024492 -0.016521   NaN -0.024806
# Arrival_Hour  0.051434     0.038123  0.024264 -0.002124   NaN  0.005215
# Arrival_Min  -0.069653    -0.106939 -0.086155 -0.021424   NaN  0.067909
#
#                Dep_Min  Arrival_Hour  Arrival_Min
# Duration     -0.018938      0.051434    -0.069653
# Total_Stops  -0.002591      0.038123    -0.106939
# Price        -0.024492      0.024264    -0.086155
# ...

# %%
plt.figure(figsize=(10,6));
sns.heatmap(a.corr(),annot=True);

# %%
a.describe().T
# Out:
#                 count         mean          std     min     25%     50%  \
# Duration      10683.0   643.093232   507.862001     5.0   170.0   520.0
# Total_Stops   10683.0     0.824207     0.675199     0.0     0.0     1.0
# Price         10683.0  9087.064121  4611.359167  1759.0  5277.0  8372.0
# Date          10683.0    12.682205     8.803701     3.0     5.0     6.0
# Year          10683.0  2019.000000     0.000000  2019.0  2019.0  2019.0
# Dep_Hour      10683.0    12.490686     5.748650     0.0     8.0    11.0
# Dep_Min       10683.0    24.411214    18.767980     0.0     5.0    25.0
# Arrival_Hour  10683.0    13.348778     6.859125     0.0     8.0    14.0
# Arrival_Min   10683.0    24.690630    16.506036     0.0    10.0    25.0
#
#                   75%      max
# Duration        930.0   2860.0
# Total_Stops       1.0      4.0
# Price         12373.0  79512.0
# Date             21.0     27.0
# Year           2019.0   2019.0
# Dep_Hour         18.0     23.0
# ...

# %%
a.describe(include="object").T
# Out:
#                  count unique              top  freq
# Airline          10683     12      Jet Airways  3849
# Source           10683      5            Delhi  4537
# Destination      10683      5           Cochin  4537
# Route            10683    128  DEL → BOM → COK  2377
# Additional_Info  10683     10          No info  8345
# Day              10683      7         Thursday  2290
# Month Name       10683      7             June  2536

# %%
a
# Out:
#            Airline    Source Destination                  Route  Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL       170
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR       445
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      1140
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR       325
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL       285
# ...            ...       ...         ...                    ...       ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR       150
# 10679    Air India   Kolkata    Banglore              CCU → BLR       155
# 10680  Jet Airways  Banglore   New Delhi              BLR → DEL       180
# 10681      Vistara  Banglore   New Delhi              BLR → DEL       160
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK       500
#
#        Total_Stops Additional_Info  Price  Date        Day Month Name  Year  \
# ...

# %%
# Change Duration

# %%
a[a["Duration"]==5.0]
# Out:
#         Airline  Source Destination                  Route  Duration  \
# 6474  Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD         5
#
#       Total_Stops Additional_Info  Price  Date     Day Month Name  Year  \
# 6474            2         No info  17327     3  Monday       June  2019
#
#       Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 6474        16       50            16           55

# %%
x=a[(a["Source"]=="Mumbai")&(a["Destination"]=="Hyderabad")&(a["Total_Stops"]==2)]
x
# Out:
#            Airline  Source Destination                  Route  Duration  \
# 597      Air India  Mumbai   Hyderabad  BOM → JDH → DEL → HYD      1775
# 1417     Air India  Mumbai   Hyderabad  BOM → AMD → ISK → HYD       795
# 1424   Jet Airways  Mumbai   Hyderabad  BOM → DED → DEL → HYD      1590
# 1784     Air India  Mumbai   Hyderabad  BOM → BHO → DEL → HYD      1995
# 1824     Air India  Mumbai   Hyderabad  BOM → JDH → DEL → HYD       845
# 2857     Air India  Mumbai   Hyderabad  BOM → COK → MAA → HYD       990
# 3294   Jet Airways  Mumbai   Hyderabad  BOM → BDQ → DEL → HYD      1665
# 3821     Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD       255
# 4402     Air India  Mumbai   Hyderabad  BOM → AMD → ISK → HYD       560
# 4659     Air India  Mumbai   Hyderabad  BOM → BHO → DEL → HYD      1795
# 4676   Jet Airways  Mumbai   Hyderabad  BOM → UDR → DEL → HYD      1415
# 5309     Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD       255
# ...

# %%
x["Duration"].mode()
# Out:
# 0     255
# 1     560
# 2     710
# 3    1795
# 4    2245
# Name: Duration, dtype: int64

# %%
round(x["Duration"].mean(),2)
# Out:
# 1101.33

# %%
a["Duration"].iloc[6474]=round(x["Duration"].mean(),2)

# %%
a.iloc[6474]
# Out:
# Airline                        Air India
# Source                            Mumbai
# Destination                    Hyderabad
# Route              BOM → GOI → PNQ → HYD
# Duration                         1101.33
# Total_Stops                            2
# Additional_Info                  No info
# Price                              17327
# Date                                   3
# Day                               Monday
# Month Name                          June
# Year                                2019
# Dep_Hour                              16
# Dep_Min                               50
# Arrival_Hour                          16
# Arrival_Min                           55
# Name: 6474, dtype: object

# %%
a.describe().T
# Out:
#                 count         mean          std     min     25%     50%  \
# Duration      10683.0   643.195856   507.843817    75.0   170.0   520.0
# Total_Stops   10683.0     0.824207     0.675199     0.0     0.0     1.0
# Price         10683.0  9087.064121  4611.359167  1759.0  5277.0  8372.0
# Date          10683.0    12.682205     8.803701     3.0     5.0     6.0
# Year          10683.0  2019.000000     0.000000  2019.0  2019.0  2019.0
# Dep_Hour      10683.0    12.490686     5.748650     0.0     8.0    11.0
# Dep_Min       10683.0    24.411214    18.767980     0.0     5.0    25.0
# Arrival_Hour  10683.0    13.348778     6.859125     0.0     8.0    14.0
# Arrival_Min   10683.0    24.690630    16.506036     0.0    10.0    25.0
#
#                   75%      max
# Duration        930.0   2860.0
# Total_Stops       1.0      4.0
# Price         12373.0  79512.0
# Date             21.0     27.0
# Year           2019.0   2019.0
# Dep_Hour         18.0     23.0
# ...

# %%
# Univariate Analyses for price

# %%
# Check Anomilies of Price .

# %%
sns.boxplot(a["Price"]);

# %%
# Check Skewness of Price .

# %%
sns.distplot(a["Price"]);

# %%
# Find the Mean , Max , Min Price

# %%
a["Price"].agg(["mean","max","min"]).reset_index()
# Out:
#   index         Price
# 0  mean   9087.064121
# 1   max  79512.000000
# 2   min   1759.000000

# %%
a["Airline"].value_counts()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
# Draw the countplot

# %%
# Find the max price of each airline .

# %%
# Find the details of expensive flight .

# %%
a[a["Airline"]=="Jet Airways"]
# Out:
#            Airline    Source Destination                  Route  Duration  \
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    1140.0
# 6      Jet Airways  Banglore   New Delhi        BLR → BOM → DEL     930.0
# 7      Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    1265.0
# 8      Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    1530.0
# 13     Jet Airways   Kolkata    Banglore        CCU → BOM → BLR     730.0
# ...            ...       ...         ...                    ...       ...
# 10668  Jet Airways     Delhi      Cochin  DEL → JDH → BOM → COK     440.0
# 10672  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    1195.0
# 10673  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK     900.0
# 10674  Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    1485.0
# 10680  Jet Airways  Banglore   New Delhi              BLR → DEL     180.0
#
#        Total_Stops              Additional_Info  Price  Date       Day  \
# ...

# %%
# Find the details of cheapest flight .

# %%
a[a["Airline"]=="Trujet"]
# Out:
#      Airline  Source Destination            Route  Duration  Total_Stops  \
# 2878  Trujet  Mumbai   Hyderabad  BOM → NDC → HYD     195.0            1
#
#      Additional_Info  Price  Date     Day Month Name  Year  Dep_Hour  Dep_Min  \
# 2878         No info   4140     3  Monday       June  2019        13        5
#
#       Arrival_Hour  Arrival_Min
# 2878            16           20

# %%
# How many flights with respect to their stops .

# %%
a["Total_Stops"].value_counts()
# Out:
# 1    5626
# 0    3491
# 2    1520
# 3      45
# 4       1
# Name: Total_Stops, dtype: int64

# %%
# Find the flights with respect to number of stops .

# %%
a.groupby("Total_Stops")["Airline"].value_counts()
# Out:
# Total_Stops  Airline
# 0            IndiGo                               1241
#              SpiceJet                              670
#              Jet Airways                           623
#              Air India                             417
#              Vistara                               264
#              Air Asia                              181
#              GoAir                                  92
#              Vistara Premium economy                 3
# 1            Jet Airways                          2535
#              Multiple carriers                    1145
#              IndiGo                                793
#              Air India                             541
#              Vistara                               215
#              SpiceJet                              148
#              Air Asia                              129
#              GoAir                                 102
#              Multiple carriers Premium economy      13
# ...

# %%
# How no of stopage varies with price .

# %%
sns.scatterplot(x="Total_Stops",y="Price",data=a);

# %%
# Which flights is available from source to destination .

# %%
a.groupby(["Source","Destination"])["Airline"].value_counts()
# Out:
# Source    Destination  Airline
# Banglore  New Delhi    Jet Airways                           788
#                        IndiGo                                523
#                        Air India                             332
#                        Vistara                               185
#                        SpiceJet                              181
#                        GoAir                                  93
#                        Air Asia                               89
#                        Jet Airways Business                    4
#                        Vistara Premium economy                 2
# Chennai   Kolkata      IndiGo                                184
#                        SpiceJet                              128
#                        Vistara                                43
#                        Air India                              25
#                        Vistara Premium economy                 1
# ...

# %%
# Find the max,min,mean Price of different flights from source of destination .

# %%
z=a.groupby(["Source","Destination","Airline"])["Price"].agg(["min","max","mean"])
z.reset_index(inplace=True)

# %%
z1=z[(z["Source"]=="Banglore")&(z["Destination"]=="New Delhi")]
z1
# Out:
#      Source Destination                  Airline    min    max          mean
# 0  Banglore   New Delhi                 Air Asia   3383  10873   4574.280899
# 1  Banglore   New Delhi                Air India   3758  31783   9238.198795
# 2  Banglore   New Delhi                    GoAir   3398  18558   4948.881720
# 3  Banglore   New Delhi                   IndiGo   3359  22153   5274.112811
# 4  Banglore   New Delhi              Jet Airways   3359  54826  11021.732234
# 5  Banglore   New Delhi     Jet Airways Business  52229  79512  62844.250000
# 6  Banglore   New Delhi                 SpiceJet   3257  23267   4550.292818
# 7  Banglore   New Delhi                  Vistara   4353  21730   6182.172973
# 8  Banglore   New Delhi  Vistara Premium economy   5969  11793   8881.000000

# %%
# Variation of price with respect to Source

# %%
sns.boxplot(x="Source",y="Price",data=a);

# %%
# Variation of price with respect to Destination .

# %%
sns.boxplot(x="Destination",y="Price",data=a);
plt.savefig("Destination_Price.jpg");

# %%
# On Which month maximum flight take off .

# %%
# Peak business month .

# %%
plt.figure(figsize=(10,6));
sns.barplot(x="Month Name",y="Price",data=a,estimator=sum);

# %%
# Which flight take off in which month .

# %%
plt.figure(figsize=(14,8));
plt.scatter(x="Airline",y="Month Name",data=a);
plt.xticks(rotation=90);

# %%
# How many flight tale off each month .

# %%
a.groupby("Month Name")["Airline"].value_counts()
# Out:
# Month Name  Airline
# April       IndiGo               153
#             SpiceJet              76
#             Jet Airways           63
#             Air India             45
#             Air Asia              32
#                                 ...
# September   Multiple carriers    160
#             SpiceJet              90
#             Vistara               61
#             Air Asia              41
#             GoAir                 23
# Name: Airline, Length: 64, dtype: int64

# %%
# How month of the journey varies with price .

# %%
plt.figure(figsize=(14,8));
sns.boxplot(x="Month Name",y="Price",data=a);

# %%
# Find the peak day .

# %%
a["Date"].value_counts()
# Out:
# 6     2166
# 5     1392
# 3     1361
# 27    1130
# 21    1111
# 24    1052
# 15     984
# 18     832
# 4      655
# Name: Date, dtype: int64

# %%
plt.figure(figsize=(14,8));
sns.barplot(x="Date",y="Price",data=a,estimator=sum);

# %%
# How day varies with price

# %%
plt.figure(figsize=(14,6));
sns.boxplot(x="Date",y="Price",data=a);

# %%
# Find the peak departure time .

# %%
a["Dep_Hour"].value_counts()
# Out:
# 9     916
# 7     867
# 8     697
# 17    695
# 6     687
# 20    651
# 5     629
# 11    580
# 19    567
# 10    536
# 14    523
# 21    492
# 16    472
# 18    444
# 13    417
# 22    387
# 15    319
# 2     194
# 12    178
# 4     170
# 23    161
# 0      40
# 1      37
# 3      24
# Name: Dep_Hour, dtype: int64

# %%
# Find the peak departure time per airline .

# %%
a.groupby("Airline")["Dep_Hour"].value_counts()
# Out:
# Airline                  Dep_Hour
# Air Asia                 7           53
#                          22          39
#                          19          37
#                          16          33
#                          23          33
#                                      ..
# Vistara                  10           1
#                          12           1
# Vistara Premium economy  7            1
#                          11           1
#                          16           1
# Name: Dep_Hour, Length: 149, dtype: int64

# %%
# Find the peak arrival time .

# %%
a["Arrival_Hour"].value_counts()
# Out:
# 19    1626
# 12     897
# 4      838
# 21     703
# 22     647
# 1      529
# 18     514
# 9      490
# 23     485
# 10     476
# 8      471
# 7      417
# 20     377
# 16     370
# 0      322
# 13     308
# 11     298
# 14     295
# 17     191
# 15     182
# 2       79
# 5       69
# 6       52
# 3       47
# Name: Arrival_Hour, dtype: int64

# %%
plt.figure(figsize=(10,6));
sns.countplot(a["Arrival_Hour"]);

# %%
# Relation between price and duration .

# %%
sns.scatterplot(x="Duration",y="Price",data=a);

# %%
a.corr()
# Out:
#               Duration  Total_Stops     Price      Date  Year  Dep_Hour  \
# Duration      1.000000     0.738403  0.506751 -0.038703   NaN  0.002125
# Total_Stops   0.738403     1.000000  0.603883 -0.024156   NaN -0.061490
# Price         0.506751     0.603883  1.000000 -0.165412   NaN  0.006819
# Date         -0.038703    -0.024156 -0.165412  1.000000   NaN -0.002251
# Year               NaN          NaN       NaN       NaN   NaN       NaN
# Dep_Hour      0.002125    -0.061490  0.006819 -0.002251   NaN  1.000000
# Dep_Min      -0.018663    -0.002591 -0.024492 -0.016521   NaN -0.024806
# Arrival_Hour  0.051514     0.038123  0.024264 -0.002124   NaN  0.005215
# Arrival_Min  -0.069284    -0.106939 -0.086155 -0.021424   NaN  0.067909
#
#                Dep_Min  Arrival_Hour  Arrival_Min
# Duration     -0.018663      0.051514    -0.069284
# Total_Stops  -0.002591      0.038123    -0.106939
# Price        -0.024492      0.024264    -0.086155
# ...

# %%
a
